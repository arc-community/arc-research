# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
for i in range(15):
    show_func_examples(f"smear_{i}")
# Out:
# # smear_0
# ------
# Example: 1/5: smear_0 (Image) -> Image
# Example: 2/5: smear_0 (Image) -> Image
# Example: 3/5: smear_0 (Image) -> Image
# Example: 4/5: smear_0 (Image) -> Image
# Example: 5/5: smear_0 (Image) -> Image
# # smear_1
# ------
# Example: 1/5: smear_1 (Image) -> Image
# Example: 2/5: smear_1 (Image) -> Image
# Example: 3/5: smear_1 (Image) -> Image
# Example: 4/5: smear_1 (Image) -> Image
# Example: 5/5: smear_1 (Image) -> Image
# # smear_2
# ------
# Example: 1/5: smear_2 (Image) -> Image
# Example: 2/5: smear_2 (Image) -> Image
# Example: 3/5: smear_2 (Image) -> Image
# Example: 4/5: smear_2 (Image) -> Image
# Example: 5/5: smear_2 (Image) -> Image
# # smear_3
# ------
# Example: 1/5: smear_3 (Image) -> Image
# Example: 2/5: smear_3 (Image) -> Image
# Example: 3/5: smear_3 (Image) -> Image
# Example: 4/5: smear_3 (Image) -> Image
# Example: 5/5: smear_3 (Image) -> Image
# # smear_4
# ------
# Example: 1/5: smear_4 (Image) -> Image
# Example: 2/5: smear_4 (Image) -> Image
# Example: 3/5: smear_4 (Image) -> Image
# Example: 4/5: smear_4 (Image) -> Image
# Example: 5/5: smear_4 (Image) -> Image
# # smear_5
# ------
# Example: 1/5: smear_5 (Image) -> Image
# Example: 2/5: smear_5 (Image) -> Image
# Example: 3/5: smear_5 (Image) -> Image
# Example: 4/5: smear_5 (Image) -> Image
# Example: 5/5: smear_5 (Image) -> Image
# # smear_6
# ------
# Example: 1/5: smear_6 (Image) -> Image
# Example: 2/5: smear_6 (Image) -> Image
# Example: 3/5: smear_6 (Image) -> Image
# Example: 4/5: smear_6 (Image) -> Image
# Example: 5/5: smear_6 (Image) -> Image
# # smear_7
# ------
# Example: 1/5: smear_7 (Image) -> Image
# Example: 2/5: smear_7 (Image) -> Image
# Example: 3/5: smear_7 (Image) -> Image
# Example: 4/5: smear_7 (Image) -> Image
# Example: 5/5: smear_7 (Image) -> Image
# # smear_8
# ------
# Example: 1/5: smear_8 (Image) -> Image
# Example: 2/5: smear_8 (Image) -> Image
# Example: 3/5: smear_8 (Image) -> Image
# Example: 4/5: smear_8 (Image) -> Image
# Example: 5/5: smear_8 (Image) -> Image
# # smear_9
# ------
# Example: 1/5: smear_9 (Image) -> Image
# Example: 2/5: smear_9 (Image) -> Image
# Example: 3/5: smear_9 (Image) -> Image
# Example: 4/5: smear_9 (Image) -> Image
# Example: 5/5: smear_9 (Image) -> Image
# # smear_10
# ------
# Example: 1/5: smear_10 (Image) -> Image
# Example: 2/5: smear_10 (Image) -> Image
# Example: 3/5: smear_10 (Image) -> Image
# Example: 4/5: smear_10 (Image) -> Image
# Example: 5/5: smear_10 (Image) -> Image
# # smear_11
# ------
# Example: 1/5: smear_11 (Image) -> Image
# Example: 2/5: smear_11 (Image) -> Image
# Example: 3/5: smear_11 (Image) -> Image
# Example: 4/5: smear_11 (Image) -> Image
# Example: 5/5: smear_11 (Image) -> Image
# # smear_12
# ------
# Example: 1/5: smear_12 (Image) -> Image
# Example: 2/5: smear_12 (Image) -> Image
# Example: 3/5: smear_12 (Image) -> Image
# Example: 4/5: smear_12 (Image) -> Image
# Example: 5/5: smear_12 (Image) -> Image
# # smear_13
# ------
# Example: 1/5: smear_13 (Image) -> Image
# Example: 2/5: smear_13 (Image) -> Image
# Example: 3/5: smear_13 (Image) -> Image
# Example: 4/5: smear_13 (Image) -> Image
# Example: 5/5: smear_13 (Image) -> Image
# # smear_14
# ------
# Example: 1/5: smear_14 (Image) -> Image
# Example: 2/5: smear_14 (Image) -> Image
# Example: 3/5: smear_14 (Image) -> Image
# Example: 4/5: smear_14 (Image) -> Image
# Example: 5/5: smear_14 (Image) -> Image
