# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
show_func_examples("border")

show_func_examples("make_border")

for b in (False, True):
    show_func_examples(f"make_border2_{b}")
    
for id in range(3):
    show_func_examples(f"connect_{id}")
# Out:
# # border
# ------
# Example: 1/5: border (Image) -> Image
# Example: 2/5: border (Image) -> Image
# Example: 3/5: border (Image) -> Image
# Example: 4/5: border (Image) -> Image
# Example: 5/5: border (Image) -> Image
# # make_border
# ------
# Example: 1/5: make_border (Image) -> Image
# Example: 2/5: make_border (Image) -> Image
# Example: 3/5: make_border (Image) -> Image
# Example: 4/5: make_border (Image) -> Image
# Example: 5/5: make_border (Image) -> Image
# # make_border2_False
# ------
# Example: 1/5: make_border2_False (Image) -> Image
# Example: 2/5: make_border2_False (Image) -> Image
# Example: 3/5: make_border2_False (Image) -> Image
# Example: 4/5: make_border2_False (Image) -> Image
# Example: 5/5: make_border2_False (Image) -> Image
# # make_border2_True
# ------
# Example: 1/5: make_border2_True (Image) -> Image
# Example: 2/5: make_border2_True (Image) -> Image
# Example: 3/5: make_border2_True (Image) -> Image
# Example: 4/5: make_border2_True (Image) -> Image
# ...
