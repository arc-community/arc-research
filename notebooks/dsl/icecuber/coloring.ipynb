# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
for i in range(10):
    show_func_examples(f"filter_color_{i}")

for i in range(1, 10):
    show_func_examples(f"erase_color_{i}")

for i in range(1, 10):
    show_func_examples(f"color_shape_const_{i}")

show_func_examples("majority_color_image")

for skipmaj in (False, True):
    show_func_examples(f"spread_colors_{1 if skipmaj else 0}")
# Out:
# # filter_color_0
# ------
# Example: 1/5: filter_color_0 (Image) -> Image
# Example: 2/5: filter_color_0 (Image) -> Image
# Example: 3/5: filter_color_0 (Image) -> Image
# Example: 4/5: filter_color_0 (Image) -> Image
# Example: 5/5: filter_color_0 (Image) -> Image
# # filter_color_1
# ------
# Example: 1/5: filter_color_1 (Image) -> Image
# Example: 2/5: filter_color_1 (Image) -> Image
# Example: 3/5: filter_color_1 (Image) -> Image
# Example: 4/5: filter_color_1 (Image) -> Image
# Example: 5/5: filter_color_1 (Image) -> Image
# # filter_color_2
# ------
# Example: 1/5: filter_color_2 (Image) -> Image
# Example: 2/5: filter_color_2 (Image) -> Image
# Example: 3/5: filter_color_2 (Image) -> Image
# Example: 4/5: filter_color_2 (Image) -> Image
# Example: 5/5: filter_color_2 (Image) -> Image
# # filter_color_3
# ------
# Example: 1/5: filter_color_3 (Image) -> Image
# Example: 2/5: filter_color_3 (Image) -> Image
# Example: 3/5: filter_color_3 (Image) -> Image
# ...
