# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
for i in range(0, 9):
    show_func_examples(f"rigid_{i}")

for i in range(4):
    show_func_examples(f"half_{i}")
# Out:
# # rigid_0
# ------
# # rigid_1
# ------
# Example: 1/5: rigid_1 (Image) -> Image
# Example: 2/5: rigid_1 (Image) -> Image
# Example: 3/5: rigid_1 (Image) -> Image
# Example: 4/5: rigid_1 (Image) -> Image
# Example: 5/5: rigid_1 (Image) -> Image
# # rigid_2
# ------
# Example: 1/5: rigid_2 (Image) -> Image
# Example: 2/5: rigid_2 (Image) -> Image
# Example: 3/5: rigid_2 (Image) -> Image
# Example: 4/5: rigid_2 (Image) -> Image
# Example: 5/5: rigid_2 (Image) -> Image
# # rigid_3
# ------
# Example: 1/5: rigid_3 (Image) -> Image
# Example: 2/5: rigid_3 (Image) -> Image
# Example: 3/5: rigid_3 (Image) -> Image
# Example: 4/5: rigid_3 (Image) -> Image
# Example: 5/5: rigid_3 (Image) -> Image
# # rigid_4
# ------
# Example: 1/5: rigid_4 (Image) -> Image
# Example: 2/5: rigid_4 (Image) -> Image
# Example: 3/5: rigid_4 (Image) -> Image
# Example: 4/5: rigid_4 (Image) -> Image
# Example: 5/5: rigid_4 (Image) -> Image
# # rigid_5
# ------
# Example: 1/5: rigid_5 (Image) -> Image
# Example: 2/5: rigid_5 (Image) -> Image
# Example: 3/5: rigid_5 (Image) -> Image
# Example: 4/5: rigid_5 (Image) -> Image
# Example: 5/5: rigid_5 (Image) -> Image
# # rigid_6
# ------
# Example: 1/5: rigid_6 (Image) -> Image
# Example: 2/5: rigid_6 (Image) -> Image
# Example: 3/5: rigid_6 (Image) -> Image
# Example: 4/5: rigid_6 (Image) -> Image
# Example: 5/5: rigid_6 (Image) -> Image
# # rigid_7
# ------
# Example: 1/5: rigid_7 (Image) -> Image
# Example: 2/5: rigid_7 (Image) -> Image
# Example: 3/5: rigid_7 (Image) -> Image
# Example: 4/5: rigid_7 (Image) -> Image
# Example: 5/5: rigid_7 (Image) -> Image
# # rigid_8
# ------
# Example: 1/5: rigid_8 (Image) -> Image
# Example: 2/5: rigid_8 (Image) -> Image
# Example: 3/5: rigid_8 (Image) -> Image
# Example: 4/5: rigid_8 (Image) -> Image
# Example: 5/5: rigid_8 (Image) -> Image
# # half_0
# ------
# Example: 1/5: half_0 (Image) -> Image
# Example: 2/5: half_0 (Image) -> Image
# Example: 3/5: half_0 (Image) -> Image
# Example: 4/5: half_0 (Image) -> Image
# Example: 5/5: half_0 (Image) -> Image
# # half_1
# ------
# Example: 1/5: half_1 (Image) -> Image
# Example: 2/5: half_1 (Image) -> Image
# Example: 3/5: half_1 (Image) -> Image
# Example: 4/5: half_1 (Image) -> Image
# Example: 5/5: half_1 (Image) -> Image
# # half_2
# ------
# Example: 1/5: half_2 (Image) -> Image
# Example: 2/5: half_2 (Image) -> Image
# Example: 3/5: half_2 (Image) -> Image
# Example: 4/5: half_2 (Image) -> Image
# Example: 5/5: half_2 (Image) -> Image
# # half_3
# ------
# Example: 1/5: half_3 (Image) -> Image
# Example: 2/5: half_3 (Image) -> Image
# Example: 3/5: half_3 (Image) -> Image
# Example: 4/5: half_3 (Image) -> Image
# Example: 5/5: half_3 (Image) -> Image
