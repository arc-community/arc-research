# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
for dy in range(-2, 3, 1):
    for dx in range(-2, 3, 1):
        if dy != 0 or dx != 0:
            show_func_examples(f"move_{dx}_{dy}")
# Out:
# # move_-2_-2
# ------
# Example: 1/5: move_-2_-2 (Image) -> Image
# Example: 2/5: move_-2_-2 (Image) -> Image
# Example: 3/5: move_-2_-2 (Image) -> Image
# Example: 4/5: move_-2_-2 (Image) -> Image
# Example: 5/5: move_-2_-2 (Image) -> Image
# # move_-1_-2
# ------
# Example: 1/5: move_-1_-2 (Image) -> Image
# Example: 2/5: move_-1_-2 (Image) -> Image
# Example: 3/5: move_-1_-2 (Image) -> Image
# Example: 4/5: move_-1_-2 (Image) -> Image
# Example: 5/5: move_-1_-2 (Image) -> Image
# # move_0_-2
# ------
# Example: 1/5: move_0_-2 (Image) -> Image
# Example: 2/5: move_0_-2 (Image) -> Image
# Example: 3/5: move_0_-2 (Image) -> Image
# Example: 4/5: move_0_-2 (Image) -> Image
# Example: 5/5: move_0_-2 (Image) -> Image
# # move_1_-2
# ------
# Example: 1/5: move_1_-2 (Image) -> Image
# Example: 2/5: move_1_-2 (Image) -> Image
# Example: 3/5: move_1_-2 (Image) -> Image
# Example: 4/5: move_1_-2 (Image) -> Image
# Example: 5/5: move_1_-2 (Image) -> Image
# # move_2_-2
# ------
# Example: 1/5: move_2_-2 (Image) -> Image
# Example: 2/5: move_2_-2 (Image) -> Image
# Example: 3/5: move_2_-2 (Image) -> Image
# Example: 4/5: move_2_-2 (Image) -> Image
# Example: 5/5: move_2_-2 (Image) -> Image
# # move_-2_-1
# ------
# Example: 1/5: move_-2_-1 (Image) -> Image
# Example: 2/5: move_-2_-1 (Image) -> Image
# Example: 3/5: move_-2_-1 (Image) -> Image
# Example: 4/5: move_-2_-1 (Image) -> Image
# Example: 5/5: move_-2_-1 (Image) -> Image
# # move_-1_-1
# ------
# Example: 1/5: move_-1_-1 (Image) -> Image
# Example: 2/5: move_-1_-1 (Image) -> Image
# Example: 3/5: move_-1_-1 (Image) -> Image
# Example: 4/5: move_-1_-1 (Image) -> Image
# Example: 5/5: move_-1_-1 (Image) -> Image
# # move_0_-1
# ------
# Example: 1/5: move_0_-1 (Image) -> Image
# Example: 2/5: move_0_-1 (Image) -> Image
# Example: 3/5: move_0_-1 (Image) -> Image
# Example: 4/5: move_0_-1 (Image) -> Image
# Example: 5/5: move_0_-1 (Image) -> Image
# # move_1_-1
# ------
# Example: 1/5: move_1_-1 (Image) -> Image
# Example: 2/5: move_1_-1 (Image) -> Image
# Example: 3/5: move_1_-1 (Image) -> Image
# Example: 4/5: move_1_-1 (Image) -> Image
# Example: 5/5: move_1_-1 (Image) -> Image
# # move_2_-1
# ------
# Example: 1/5: move_2_-1 (Image) -> Image
# Example: 2/5: move_2_-1 (Image) -> Image
# Example: 3/5: move_2_-1 (Image) -> Image
# Example: 4/5: move_2_-1 (Image) -> Image
# Example: 5/5: move_2_-1 (Image) -> Image
# # move_-2_0
# ------
# Example: 1/5: move_-2_0 (Image) -> Image
# Example: 2/5: move_-2_0 (Image) -> Image
# Example: 3/5: move_-2_0 (Image) -> Image
# Example: 4/5: move_-2_0 (Image) -> Image
# Example: 5/5: move_-2_0 (Image) -> Image
# # move_-1_0
# ------
# Example: 1/5: move_-1_0 (Image) -> Image
# Example: 2/5: move_-1_0 (Image) -> Image
# Example: 3/5: move_-1_0 (Image) -> Image
# Example: 4/5: move_-1_0 (Image) -> Image
# Example: 5/5: move_-1_0 (Image) -> Image
# # move_1_0
# ------
# Example: 1/5: move_1_0 (Image) -> Image
# Example: 2/5: move_1_0 (Image) -> Image
# Example: 3/5: move_1_0 (Image) -> Image
# Example: 4/5: move_1_0 (Image) -> Image
# Example: 5/5: move_1_0 (Image) -> Image
# # move_2_0
# ------
# Example: 1/5: move_2_0 (Image) -> Image
# Example: 2/5: move_2_0 (Image) -> Image
# Example: 3/5: move_2_0 (Image) -> Image
# Example: 4/5: move_2_0 (Image) -> Image
# Example: 5/5: move_2_0 (Image) -> Image
# # move_-2_1
# ------
# Example: 1/5: move_-2_1 (Image) -> Image
# Example: 2/5: move_-2_1 (Image) -> Image
# Example: 3/5: move_-2_1 (Image) -> Image
# Example: 4/5: move_-2_1 (Image) -> Image
# Example: 5/5: move_-2_1 (Image) -> Image
# # move_-1_1
# ------
# Example: 1/5: move_-1_1 (Image) -> Image
# Example: 2/5: move_-1_1 (Image) -> Image
# Example: 3/5: move_-1_1 (Image) -> Image
# Example: 4/5: move_-1_1 (Image) -> Image
# Example: 5/5: move_-1_1 (Image) -> Image
# # move_0_1
# ------
# Example: 1/5: move_0_1 (Image) -> Image
# Example: 2/5: move_0_1 (Image) -> Image
# Example: 3/5: move_0_1 (Image) -> Image
# Example: 4/5: move_0_1 (Image) -> Image
# Example: 5/5: move_0_1 (Image) -> Image
# # move_1_1
# ------
# Example: 1/5: move_1_1 (Image) -> Image
# Example: 2/5: move_1_1 (Image) -> Image
# Example: 3/5: move_1_1 (Image) -> Image
# Example: 4/5: move_1_1 (Image) -> Image
# Example: 5/5: move_1_1 (Image) -> Image
# # move_2_1
# ------
# Example: 1/5: move_2_1 (Image) -> Image
# Example: 2/5: move_2_1 (Image) -> Image
# Example: 3/5: move_2_1 (Image) -> Image
# Example: 4/5: move_2_1 (Image) -> Image
# Example: 5/5: move_2_1 (Image) -> Image
# # move_-2_2
# ------
# Example: 1/5: move_-2_2 (Image) -> Image
# Example: 2/5: move_-2_2 (Image) -> Image
# Example: 3/5: move_-2_2 (Image) -> Image
# Example: 4/5: move_-2_2 (Image) -> Image
# Example: 5/5: move_-2_2 (Image) -> Image
# # move_-1_2
# ------
# Example: 1/5: move_-1_2 (Image) -> Image
# Example: 2/5: move_-1_2 (Image) -> Image
# Example: 3/5: move_-1_2 (Image) -> Image
# Example: 4/5: move_-1_2 (Image) -> Image
# Example: 5/5: move_-1_2 (Image) -> Image
# # move_0_2
# ------
# Example: 1/5: move_0_2 (Image) -> Image
# Example: 2/5: move_0_2 (Image) -> Image
# Example: 3/5: move_0_2 (Image) -> Image
# Example: 4/5: move_0_2 (Image) -> Image
# Example: 5/5: move_0_2 (Image) -> Image
# # move_1_2
# ------
# Example: 1/5: move_1_2 (Image) -> Image
# Example: 2/5: move_1_2 (Image) -> Image
# Example: 3/5: move_1_2 (Image) -> Image
# Example: 4/5: move_1_2 (Image) -> Image
# Example: 5/5: move_1_2 (Image) -> Image
# # move_2_2
# ------
# Example: 1/5: move_2_2 (Image) -> Image
# Example: 2/5: move_2_2 (Image) -> Image
# Example: 3/5: move_2_2 (Image) -> Image
# Example: 4/5: move_2_2 (Image) -> Image
# Example: 5/5: move_2_2 (Image) -> Image
