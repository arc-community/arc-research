# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
show_func_examples("cut_image")
show_func_examples("split_colors")
show_func_examples("split_all")
show_func_examples("split_columns")
show_func_examples("split_rows")
show_func_examples("inside_marked")
for d in range(4):
    show_func_examples(f"gravity_{d}")
# Out:
# # cut_image
# ------
# Example: 1/5: cut_image (Image) -> ImageList
# Example: 2/5: cut_image (Image) -> ImageList
# Example: 3/5: cut_image (Image) -> ImageList
# Example: 4/5: cut_image (Image) -> ImageList
# Example: 5/5: cut_image (Image) -> ImageList
# # split_colors
# ------
# Example: 1/5: split_colors (Image) -> ImageList
# Example: 2/5: split_colors (Image) -> ImageList
# Example: 3/5: split_colors (Image) -> ImageList
# Example: 4/5: split_colors (Image) -> ImageList
# Example: 5/5: split_colors (Image) -> ImageList
# # split_all
# ------
# Example: 1/5: split_all (Image) -> ImageList
# Example: 2/5: split_all (Image) -> ImageList
# Example: 3/5: split_all (Image) -> ImageList
# Example: 4/5: split_all (Image) -> ImageList
# Example: 5/5: split_all (Image) -> ImageList
# # split_columns
# ------
# Example: 1/5: split_columns (Image) -> ImageList
# Example: 2/5: split_columns (Image) -> ImageList
# Example: 3/5: split_columns (Image) -> ImageList
# ...
