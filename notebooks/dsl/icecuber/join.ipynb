# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
show_func_examples("pick_unique")
show_func_examples("compose_growing")
show_func_examples("stack_line")

for id in range(4):
    show_func_examples(f"my_stack_list_{id}")

for id in range(14):
    show_func_examples(
        f"pick_max_{id}"
    )
# Out:
# # pick_unique
# ------
# Example: 1/5: pick_unique (ImageList) -> Image
# Example: 2/5: pick_unique (ImageList) -> Image
# Example: 3/5: pick_unique (ImageList) -> Image
# Example: 4/5: pick_unique (ImageList) -> Image
# Example: 5/5: pick_unique (ImageList) -> Image
# # compose_growing
# ------
# Example: 1/5: compose_growing (ImageList) -> Image
# Example: 2/5: compose_growing (ImageList) -> Image
# Example: 3/5: compose_growing (ImageList) -> Image
# Example: 4/5: compose_growing (ImageList) -> Image
# Example: 5/5: compose_growing (ImageList) -> Image
# # stack_line
# ------
# Example: 1/5: stack_line (ImageList) -> Image
# Example: 2/5: stack_line (ImageList) -> Image
# Example: 3/5: stack_line (ImageList) -> Image
# Example: 4/5: stack_line (ImageList) -> Image
# Example: 5/5: stack_line (ImageList) -> Image
# # my_stack_list_0
# ------
# Example: 1/5: my_stack_list_0 (ImageList) -> Image
# Example: 2/5: my_stack_list_0 (ImageList) -> Image
# ...
