# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
show_func_examples("compress")
show_func_examples("compress2")
show_func_examples("compress3")
# Out:
# # compress
# ------
# Example: 1/5: compress (Image) -> Image
# Example: 2/5: compress (Image) -> Image
# Example: 3/5: compress (Image) -> Image
# Example: 4/5: compress (Image) -> Image
# Example: 5/5: compress (Image) -> Image
# # compress2
# ------
# Example: 1/5: compress2 (Image) -> Image
# Example: 2/5: compress2 (Image) -> Image
# Example: 3/5: compress2 (Image) -> Image
# Example: 4/5: compress2 (Image) -> Image
# Example: 5/5: compress2 (Image) -> Image
# # compress3
# ------
# Example: 1/5: compress3 (Image) -> Image
# Example: 2/5: compress3 (Image) -> Image
# Example: 3/5: compress3 (Image) -> Image
# Example: 4/5: compress3 (Image) -> Image
# Example: 5/5: compress3 (Image) -> Image
