# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
show_func_examples("get_pos")
show_func_examples("get_size")
show_func_examples("get_size0")
show_func_examples("hull")
show_func_examples("hull0")
show_func_examples("to_origin")
show_func_examples("fill")
show_func_examples("interior")
show_func_examples("interior2")
show_func_examples("center")
# Out:
# # get_pos
# ------
# Example: 1/5: get_pos (Image) -> Image
# Example: 2/5: get_pos (Image) -> Image
# Example: 3/5: get_pos (Image) -> Image
# Example: 4/5: get_pos (Image) -> Image
# Example: 5/5: get_pos (Image) -> Image
# # get_size
# ------
# Example: 1/5: get_size (Image) -> Image
# Example: 2/5: get_size (Image) -> Image
# Example: 3/5: get_size (Image) -> Image
# Example: 4/5: get_size (Image) -> Image
# Example: 5/5: get_size (Image) -> Image
# # get_size0
# ------
# Example: 1/5: get_size0 (Image) -> Image
# Example: 2/5: get_size0 (Image) -> Image
# Example: 3/5: get_size0 (Image) -> Image
# Example: 4/5: get_size0 (Image) -> Image
# Example: 5/5: get_size0 (Image) -> Image
# # hull
# ------
# Example: 1/5: hull (Image) -> Image
# Example: 2/5: hull (Image) -> Image
# Example: 3/5: hull (Image) -> Image
# Example: 4/5: hull (Image) -> Image
# Example: 5/5: hull (Image) -> Image
# # hull0
# ------
# Example: 1/5: hull0 (Image) -> Image
# ...
