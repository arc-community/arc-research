# %%
from helper import load_func_examples
show_func_examples = load_func_examples()

# %%
show_func_examples("embed")
show_func_examples("wrap")
show_func_examples("broadcast")
show_func_examples("repeat_0")
show_func_examples("repeat_1")
show_func_examples("mirror_0")
show_func_examples("mirror_1")
show_func_examples("filter_color_palette")
show_func_examples("replace_colors")
# Out:
# # embed
# ------
# Example: 1/5: embed (Image,Image) -> Image
# Example: 2/5: embed (Image,Image) -> Image
# Example: 3/5: embed (Image,Image) -> Image
# Example: 4/5: embed (Image,Image) -> Image
# Example: 5/5: embed (Image,Image) -> Image
# # wrap
# ------
# Example: 1/5: wrap (Image,Image) -> Image
# Example: 2/5: wrap (Image,Image) -> Image
# Example: 3/5: wrap (Image,Image) -> Image
# Example: 4/5: wrap (Image,Image) -> Image
# Example: 5/5: wrap (Image,Image) -> Image
# # broadcast
# ------
# Example: 1/5: broadcast (Image,Image) -> Image
# Example: 2/5: broadcast (Image,Image) -> Image
# Example: 3/5: broadcast (Image,Image) -> Image
# Example: 4/5: broadcast (Image,Image) -> Image
# Example: 5/5: broadcast (Image,Image) -> Image
# # repeat_0
# ------
# Example: 1/5: repeat_0 (Image,Image) -> Image
# Example: 2/5: repeat_0 (Image,Image) -> Image
# Example: 3/5: repeat_0 (Image,Image) -> Image
# Example: 4/5: repeat_0 (Image,Image) -> Image
# ...
